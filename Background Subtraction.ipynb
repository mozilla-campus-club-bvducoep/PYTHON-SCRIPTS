# %%
import numpy as np 
import cv2 
  
cap = cv2.VideoCapture("D:/output samples/Bitwise.wmv") 
fgbg = cv2.createBackgroundSubtractorMOG2() 
  
while(1): 
    ret, frame = cap.read() 
  
    fgmask = fgbg.apply(frame) 
   
    cv2.imshow('fgmask',fgmask) 
    cv2.imshow('frame',frame) 
  
      
    k = cv2.waitKey(60) & 0xff
    if k == 27: 
        break  
cap.release() 
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-256d8f144a62> in <module>
#      10     fgmask = fgbg.apply(frame)
#      11
# ---> 12     cv2.imshow('fgmask',fgmask)
#      13     cv2.imshow('frame',frame)
#      14
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\highgui\src\window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'
